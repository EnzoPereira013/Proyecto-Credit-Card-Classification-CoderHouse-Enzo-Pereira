# %% [markdown]
# # Pyecto de Data Science - Enzo Pereira
#
# ## Dataset: Credit Card Classification.
#
# #### La puntuación crediticia es un método común de control de riesgos en la industria financiera. Utiliza la información personal y los datos presentados por los solicitantes de tarjetas de crédito para predecir la probabilidad de futuros incumplimientos y préstamos de tarjetas de crédito. El banco puede decidir si emite una tarjeta de crédito al solicitante. Los puntajes de crédito pueden cuantificar objetivamente la magnitud del riesgo.
# #### En términos generales, la puntuación de crédito se basan en datos históricos. Una vez que se encuentra con grandes fluctuaciones económicas. Los modelos anteriores pueden perder su poder predictivo original.
#
#
# ### Variables destacables:
# * ID
# * Own_Car
# * Own_Property
# * Unemployed
# * Num_Children
# * Num_Family
# * Age
# * Years_Employed
#
#
# ##Línea de investigación a seguir:
# * Crear un modelo con el fin de predecir la probabilidad de futuros incumplimientos de solicitante en base a sus datos personales y puntuación de crédito.
#
# ## Descripción del DF:
# * Género: 1 masculino - 0 femenino
# * Carro propio: 1 si - 0 no
# * Propiedad propia: 1 si - 0 no
# * Teléfono del trabajo: 1 si - 0 no
# * Teléfono: 1 si - 0 no
# * Correo electrónico: 1 si - 0 no
# * Desempleado: 1 si - 0 no
# * Número de hijos: Numero de hijos
# * Miembros de la familia: Número de miembros de la familia
# * Longitud de la cuenta:Número de meses que se ha tenido la tarjeta de crédito
# * Ingresos totales: Ingreso total (yuan chino)
# * Edad: Edad en años
# * Años empleados: Número de años de trabajo
# * Tipo de ingreso: Tipo de ingreso
# * Tipo de educación: Nivel educativo
# * Situación familiar: Estado civil
# * Tipo de vivienda: Tipo de vivienda
# * Tipo de ocupación: Tipo de empleo
# * Objetivo: 1=alto riesgo - 0=bajo riesgo

# %%
import pandas as pd

# %%
df = pd.read_csv ('/content/drive/MyDrive/Data Science/Data Science /Primer entrega Data Science /Credit Card Classification Enzo Pereira/Credit Card Classification.csv')

# %%
df
# Out:
#            ID  Gender  Own_car  Own_property  Work_phone  Phone  Email  \
# 0     5008804       1        1             1           1      0      0
# 1     5008806       1        1             1           0      0      0
# 2     5008808       0        0             1           0      1      1
# 3     5008812       0        0             1           0      0      0
# 4     5008815       1        1             1           1      1      1
# ...       ...     ...      ...           ...         ...    ...    ...
# 9704  5148694       0        0             0           0      0      0
# 9705  5149055       0        0             1           1      1      0
# 9706  5149729       1        1             1           0      0      0
# 9707  5149838       0        0             1           0      1      1
# 9708  5150337       1        0             1           0      0      0
#
#       Unemployed  Num_children  Num_family  Account_length  Total_income  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9709 entries, 0 to 9708
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               9709 non-null   int64
#  1   Gender           9709 non-null   int64
#  2   Own_car          9709 non-null   int64
#  3   Own_property     9709 non-null   int64
#  4   Work_phone       9709 non-null   int64
#  5   Phone            9709 non-null   int64
#  6   Email            9709 non-null   int64
#  7   Unemployed       9709 non-null   int64
#  8   Num_children     9709 non-null   int64
#  9   Num_family       9709 non-null   int64
#  10  Account_length   9709 non-null   int64
#  11  Total_income     9709 non-null   float64
#  12  Age              9709 non-null   float64
#  13  Years_employed   9709 non-null   float64
#  14  Income_type      9709 non-null   object
#  15  Education_type   9709 non-null   object
#  16  Family_status    9709 non-null   object
# ...

# %%
df.head()
# Out:
#         ID  Gender  Own_car  Own_property  Work_phone  Phone  Email  \
# 0  5008804       1        1             1           1      0      0
# 1  5008806       1        1             1           0      0      0
# 2  5008808       0        0             1           0      1      1
# 3  5008812       0        0             1           0      0      0
# 4  5008815       1        1             1           1      1      1
#
#    Unemployed  Num_children  Num_family  Account_length  Total_income  \
# 0           0             0           2              15      427500.0
# 1           0             0           2              29      112500.0
# 2           0             0           1               4      270000.0
# 3           1             0           1              20      283500.0
# 4           0             0           2               5      270000.0
#
#          Age  Years_employed           Income_type  \
# 0  32.868574       12.435574               Working
# ...

# %%
df. describe ()
# Out:
#                  ID       Gender      Own_car  Own_property   Work_phone  \
# count  9.709000e+03  9709.000000  9709.000000   9709.000000  9709.000000
# mean   5.076105e+06     0.348749     0.367700      0.671542     0.217427
# std    4.080270e+04     0.476599     0.482204      0.469677     0.412517
# min    5.008804e+06     0.000000     0.000000      0.000000     0.000000
# 25%    5.036955e+06     0.000000     0.000000      0.000000     0.000000
# 50%    5.069449e+06     0.000000     0.000000      1.000000     0.000000
# 75%    5.112986e+06     1.000000     1.000000      1.000000     0.000000
# max    5.150479e+06     1.000000     1.000000      1.000000     1.000000
#
#              Phone        Email   Unemployed  Num_children   Num_family  \
# count  9709.000000  9709.000000  9709.000000   9709.000000  9709.000000
# mean      0.287671     0.087548     0.174683      0.422804     2.182614
# std       0.452700     0.282650     0.379716      0.767019     0.932918
# ...

# %% [markdown]
# #Visualizaciones de datos.

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# #Graficas en matplotlib:

# %%
mpl.style.use ('bmh')

# %% [markdown]
# ##Distribución de la muestra según género:

# %%
gender_counts = df['Gender'].value_counts()

# %%
fig, ax = plt.subplots()
ax.bar(gender_counts.index, gender_counts.values)
ax.set_title('Distribución de la población según género')
ax.set_xlabel('Género')
ax.set_ylabel('Número de individuos')
ax.set_xticks([0, 1])
ax.set_xticklabels(['Masculino', 'Femenino'])
ax.legend(['Cantidad'])
plt.show()

# %% [markdown]
# #### En esta gráfica podemos observar la distribución de la muestra según el género, como se puede apreciar hay mayor cantidad de individuos del género masculino, practicamente duplicando el número del género femenino.

# %% [markdown]
# ## Clasificación de la muestra según el tipo de ingreso:

# %%
income_sources = df['Income_type'].value_counts()

# %%
fig, ax = plt.subplots()
ax.pie(income_sources.values, labels=income_sources.index, autopct='%1.1f%%')
ax.set_title('Fuentes de ingresos')
# Out:
# Text(0.5, 1.0, 'Fuentes de ingresos')

# %% [markdown]
# #### En esta gráfica podemos observar las diferentes fuentes de ingresos de los individuos de la muestra, cabe resaltar que la mayoria de los solicitantes son trabajadores.

# %% [markdown]
# ##Distribución de la muestra según presencia o no de riesgo de incumplimiento

# %%
target_counts = df['Target'].value_counts()

# %%
fig, ax = plt.subplots()
ax.bar(target_counts.index, target_counts.values)
ax.set_title('Distribución de la población según riesgo')
ax.set_xlabel('Riesgo')
ax.set_ylabel('Número de individuos')
ax.set_xticks([0, 1])
ax.set_xticklabels(['Sin riesgo', 'Presenta riesgo'])
ax.legend(['Cantidad'])
plt.show()

# %% [markdown]
# #### En esta gráfica se compara la cantidad de individuos que presentan riesgo de incumplimiento de pago de su targeta de crédito en comparación a los que no presentan riesgo, podemos observar que en su mayoría no presentan riesgo.

# %% [markdown]
# #Gráficas en seaborn:

# %%
edu_levels = df['Education_type'].value_counts()

# %%
sns.set_style('whitegrid')
sns.countplot(x='Education_type', data=df, order=edu_levels.index)
plt.title('Niveles educativos de la muestra')
plt.xlabel('Nivel educativo')
plt.ylabel('Número de individuos')
plt.xticks(rotation=90)
# Out:
# (array([0, 1, 2, 3, 4]),
#  [Text(0, 0, 'Secondary / secondary special'),
#   Text(1, 0, 'Higher education'),
#   Text(2, 0, 'Incomplete higher'),
#   Text(3, 0, 'Lower secondary'),
#   Text(4, 0, 'Academic degree')])

# %% [markdown]
# #### En la presente gráfica se comparan los diferentes niveles educativos de la muestra, se puede observar una prevalencia importante del nivel secundario.

# %%
civil_status = df['Family_status'].value_counts()
sns.set_style('whitegrid')
fig, ax = plt.subplots()
ax.pie(civil_status.values, labels=civil_status.index, autopct='%1.1f%%')
plt.title('Estados civiles de la muestra')
plt.show()

# %% [markdown]
# #### En esta gráfica podemos observar los diferentes estados civiles de la población, se puede destacar que la mayoría se encuentra casado, seguido por soltero y únion civil.

# %%
edu_salary = df[['Education_type', 'Total_income']]
sns.set_style('whitegrid')
sns.relplot(x='Education_type', y='Total_income', data=edu_salary)
plt.title('Relación entre nivel educativo y salario')
plt.xlabel('Nivel educativo')
plt.ylabel('Salario')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### En esta gráfica podemos observar la relación entre los ingresos totales y el nivel educativo de los individuos, se puede ver que la educación superior es quien poresenta un mayor ingreso total en relación a los demás niveles.

# %% [markdown]
# #Estructurando proyecto de DS.

# %% [markdown]
# ## Abstract:
# #### El presente proyecto presenta un modelo de clasificación de solicitantes de tarjetas de crédito, la clasificación de crédito es un problema común en la industria financiera y este proyecto tiene como objetivo crear un modelo de clasificación preciso y eficiente.
# #### Se clasificará a los solicitantes en presencia o no de riesgo de incumplimientos y para entrenar y probar el modelo se utilizará una base de datos obtenida en Kaggle.
# #### La metodología a utilizar será de aprendizaje supervisado con el fin de crear un modelo de clasificación, las variables más importantes que se utilizarán para el entrenamiento serán: Desempleado, Longitud de la cuenta, Ingresos totales, Edad, Años empleados, Tipo de ingreso, Tipo de educación, Tipo de ocupación y Objetivo.
# #### La audiencia a la cual va dirigida este proyecto es en un principio coderhouse y también a entidades bancarias que les interese implementar este tipo de modelos.
# # Preguntas problema:
# #### ¿Cuáles son las variables más importantes para la clasificación de tarjetas de crédito?
# #### ¿Cómo se pueden utilizar técnicas de aprendizaje automático para clasificar el riesgo de crédito de manera más precisa que los métodos existentes?
# #### ¿Cómo se pueden aplicar los resultados del modelo en tiempo real para detectar y prevenir los riesgos?
# #### ¿Cómo se pueden incorporar nuevas variables y datos a medida que cambian las tendencias y patrones en la industria de las tarjetas de crédito?
#
# ## Hipótesis:
# #### 1)
# #### h0: Al utilizar técnicas de aprendizaje automático, no posible crear un modelo de clasificación de crédito que tenga una mayor precisión en la detección de riesgos que los métodos existentes.
# #### h1: Al utilizar técnicas de aprendizaje automático, es posible crear un modelo de clasificación de crédito que tenga una mayor precisión en la detección de riesgos que los métodos existentes.
# #### 2)
# #### h0:  No existe relación significativa entre desempleo y riesgo de incumplimientos crediticio.
# #### h1: Existe relación significativa entre desempleo y riesgo de incumplimientos crediticios.

# %% [markdown]
# # EDA:

# %% [markdown]
# ##Relación entre desempleo y riesgo

# %%
tabla_contingencia_Desempleo_incumplimiento = pd.crosstab(df["Unemployed"], df["Target"])
print(tabla_contingencia_Desempleo_incumplimiento)
# Out:
# Target         0     1
# Unemployed
# 0           6923  1090
# 1           1503   193

# %%
sns.heatmap(tabla_contingencia_Desempleo_incumplimiento, annot=True, cmap="YlGnBu")
plt.show()

# %%
from scipy.stats import chi2_contingency

# %%
resultado_prueba, p_valor, grados_libertad, esperados = chi2_contingency(tabla_contingencia_Desempleo_incumplimiento)
print("Resultado de la prueba de chi-cuadrado:", resultado_prueba)
print("P-valor:", p_valor)
# Out:
# Resultado de la prueba de chi-cuadrado: 5.840184368775942
# P-valor: 0.01566418520314108

# %% [markdown]
# ## Para esta prueba de establecio un nivel de significancia de 0,05 para el resultado de P-valor.
# #### Al observar los resultados de la prueba de chi-cuadrado y el P-valor podemos decir que al ser P-valor < que el nivel de significancia establecido y al ser el valor de chi2 5.840 con 9709 grados de libertad indica que existe una discrepancia entre los datos observados y los datos esperados, por lo tanto podemos rechazar h0.

# %%
df = df.drop('ID', axis=1)

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(method='spearman'), annot=True, fmt='.0%')
plt.show()
# Out:
# <ipython-input-24-af553fc8897e>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(method='spearman'), annot=True, fmt='.0%')

# %% [markdown]
# #### Al observar el heatmap podemos ver que las variables que tienen un mayor relación con la variable objetivo son las variables edad, desempleado, familia numerosa, dueño de propiedad, dueño de auto y teléfono, meintras que la con menor relación es el largo de cuenta.

# %% [markdown]
# ## Aplicación de V de Cramer

# %%
# !pip install researchpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import researchpy as rp
import scipy.stats as ss

# %%
def cramers_v(confusion_matrix):
    """ calculate Cramers V 
    """
    chi2 = ss.chi2_contingency(confusion_matrix)[0]
    n = confusion_matrix.sum()
    phi2 = chi2 / n
    r, k = confusion_matrix.shape
    phi2corr = max(0, phi2 - ((k-1)*(r-1))/(n-1))
    rcorr = r - ((r-1)**2)/(n-1)
    kcorr = k - ((k-1)**2)/(n-1)
    return np.sqrt(phi2corr / min((kcorr-1), (rcorr-1)))

# %%
df['Target'] = pd.to_numeric(df['Target'], errors='coerce')
df.dropna(subset=['Target'], inplace=True)
df['Target'] = pd.cut(df['Target'], bins=[-np.inf, 0, np.inf], labels=['No', 'Yes'])

# %%
datos_numericos = df.select_dtypes(include=np.number)
datos_categoricos = df.select_dtypes(include='object')

# %%
resultados = []
for var1 in datos_categoricos.columns:
    fila = []
    for var2 in datos_categoricos.columns:
        if var1 != var2:
            tabla_contingencia = pd.crosstab(datos_categoricos[var1], datos_categoricos[var2])
            v_cramer = cramers_v(tabla_contingencia.values)
            fila.append(v_cramer) 
        else: 
            fila.append(1.0)
    tabla_contingencia = pd.crosstab(datos_categoricos[var1], df['Target'])
    v_cramer = cramers_v(tabla_contingencia.values)
    fila.append(v_cramer)
    resultados.append(fila)

# %%
resultados_df = pd.DataFrame(resultados, columns=datos_categoricos.columns.tolist() + ['Target'])
resultados_df.set_index(resultados_df.columns.tolist(), inplace=True)

# %%
sns.heatmap(resultados, annot=True, xticklabels=datos_categoricos.columns.tolist()+['Target'], yticklabels=datos_categoricos.columns.tolist()+['Target'])
# Out:
# <Axes: >

# %% [markdown]
# #### La V de Cramer es una medida útil para determinar si hay una asociación significativa entre dos variables categóricas y para cuantificar la fuerza de esta asociación. Esta medida varía entre 0 y 1, donde 0 indica que no hay asociación entre las variables y 1 indica una asociación perfecta. Al aplicar esto podemos observar con mayor claridad la asiciación de las variables categoricas de de nuestro DF, cabe destacar que las variables con mayor asociación a la variable objetivo son nivel educativo y la situación familiar.

# %% [markdown]
# ##Objetivo primario:
#
# #### El objetivo es proporcionar a las instituciones financieras una herramienta efectiva para evaluar el riesgo crediticio y tomar decisiones informadas sobre la aprobación, el monto del préstamo y las tasas de interés. Al lograr este objetivo, el modelo busca minimizar el riesgo de incumplimiento y las pérdidas asociadas, al tiempo que maximiza la rentabilidad y la eficiencia operativa de la institución.
#
# ## Objetivo secundario:
#
# #### Aumentar la equidad y la transparencia en el proceso de evaluación de crédito, al reducir la influencia de sesgos subjetivos o discriminatorios. Al utilizar un modelo basado en datos y algoritmos objetivos, se busca asegurar una evaluación justa y consistente para todos los solicitantes, promoviendo la igualdad de oportunidades en el acceso al crédito.

# %% [markdown]
# ## Problema comercial:
#
# #### La creación de un modelo de ciencia de datos para la clasificación de riesgo crediticio puede ayudar a resolver problemas comerciales al mejorar la precisión de las decisiones de crédito, optimizar los recursos financieros, automatizar el proceso de evaluación de crédito y mitigar el sesgo humano en la toma de decisiones.
#
# #### Toma de decisiones más precisas: Un modelo de clasificación de riesgo crediticio bien entrenado y validado puede proporcionar una evaluación más precisa del riesgo asociado a los solicitantes de crédito. Esto ayuda a las instituciones financieras a tomar decisiones más informadas y fundamentadas al otorgar préstamos, lo que puede reducir el riesgo de incumplimiento y pérdidas financieras.
#
# #### Optimización de los recursos financieros: Al tener un modelo de clasificación de riesgo crediticio confiable, las instituciones financieras pueden asignar sus recursos de manera más eficiente. Pueden identificar y priorizar a los solicitantes de bajo riesgo, permitiéndoles enfocar sus esfuerzos en aquellos con mayor probabilidad de cumplir con sus obligaciones crediticias. Esto ayuda a optimizar el flujo de efectivo y mejorar la rentabilidad general de la institución.
#
# #### Automatización del proceso de evaluación de crédito: Al implementar un modelo de clasificación de riesgo crediticio, las instituciones financieras pueden automatizar gran parte del proceso de evaluación de crédito. Esto agiliza el proceso de toma de decisiones y reduce la carga de trabajo manual asociada a la revisión de solicitudes. Como resultado, se puede mejorar la eficiencia operativa y la capacidad de respuesta a los clientes.
#
# #### Mitigación del sesgo humano: La evaluación de crédito realizada por humanos puede verse influenciada por sesgos subjetivos. Al utilizar un modelo de clasificación de riesgo crediticio objetivo y basado en datos, se reduce la posibilidad de sesgo humano en la toma de decisiones. Esto ayuda a garantizar una evaluación justa y equitativa para todos los solicitantes, independientemente de factores subjetivos o discriminatorios.
#
# ## Contexto Comercial:
#
# #### Para las empresas que prestan servicios finiancieros el incumlimiento de pagos por parte de los usuarios de líneas de crédito podría representan perdidas importantes, teniendo esto en cuenta es importante la creación de un modelo que puda prevenir estos posibles incumplimientos con el fin de disminuir estos riesgos.
#
# ##Contexto analítico:
#
# #### Se cuenta con un Dataset de diferentes solicitantes  de tarjetas de crédito que contiene diversas variables con las cuales se pretende entrenar al modelo con el fin de que pueda detectar los riesgos existentes.
# #### Para esto se hará uso de diversas librerias y modelos que faciliten el procesamiento de los datos y el posterir entrenamiento del modelo.

# %% [markdown]
# # Balance de clases

# %%
y = df['Target']

# %%
class_counts = pd.Series(y).value_counts()
print(class_counts)
# Out:
# No     8426
# Yes    1283
# Name: Target, dtype: int64

# %%
class_counts.plot(kind='bar')
plt.xlabel('Clase')
plt.ylabel('Número de muestras')
plt.show()

# %%
class_percentages = class_counts / len(y) * 100
print(class_percentages)
# Out:
# No     86.785457
# Yes    13.214543
# Name: Target, dtype: float64

# %% [markdown]
# #### Al realizar diferentes cálculos y visualizaciones se logra observar un claro desblance en las clases, por lo que se procederá a realizar el balance de las mismas pero antes se aplicará One-Hot Encoding para asegurarnos de que todas las categorias sean numéricas para que luego sean procesadas por el modelo.
# #### Luego se procederá con el balance de clases, la reducción de la dimensionalidad y el entrenamiento del modelo.

# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder
from imblearn.over_sampling import SMOTE
from sklearn.decomposition import TruncatedSVD
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, precision_score, recall_score, f1_score

# %%
categorical_columns = ['Gender', 'Own_car', 'Own_property', 'Work_phone', 'Phone', 'Email', 'Unemployed', 'Income_type', 'Education_type', 'Family_status', 'Housing_type', 'Occupation_type']
X_encoded = pd.get_dummies(df, columns=categorical_columns)

# %%
encoder = OneHotEncoder()
X_encoded_encoded = encoder.fit_transform(X_encoded)

# %%
smote = SMOTE(random_state=42)
X_balanced, y_balanced = smote.fit_resample(X_encoded_encoded, y)

# %%
svd = TruncatedSVD(n_components=2)
X_svd = svd.fit_transform(X_encoded_encoded)

# %%
df_svd = pd.DataFrame(X_svd, columns=['Componente_1', 'Componente_2'])
print(df_svd)
# Out:
#       Componente_1  Componente_2
# 0         6.207665     -1.255299
# 1         6.986410     -1.166771
# 2         6.507335      0.485292
# 3         6.595960      2.768758
# 4         6.303808     -1.947531
# ...            ...           ...
# 9704      6.458552      0.706244
# 9705      6.753366      0.489329
# 9706      6.958717     -0.675190
# 9707      6.441762      0.791170
# 9708      6.532055     -0.570575
#
# [9709 rows x 2 columns]

# %% [markdown]
# ## Para este proyecto se ha optado por un modelo de clasificación de random forest por los siguientes motivos:
#
# ## Capacidad para manejar características no lineales:
# #### Random Forest es un algoritmo basado en árboles de decisión que tiene la capacidad de capturar relaciones no lineales entre las características y el objetivo. Esto es importante en problemas de clasificación de crédito, donde las relaciones pueden ser complejas y no lineales.
#
# ## Robustez frente a datos desbalanceados:
# #### Random Forest es robusto frente a conjuntos de datos desbalanceados, donde la proporción de instancias positivas y negativas en el objetivo puede estar desequilibrada. Esto es relevante en este caso ya que generalmente hay una proporción desigual entre los clientes que cumplen con sus pagos y los que no.
#
# ## Reducción del sobreajuste:
# #### Gracias a la técnica llamada "bagging" que combina múltiples árboles de decisión entrenados en diferentes subconjuntos de datos. Esto ayuda a reducir el sobreajuste y mejora la generalización del modelo. En el contexto de clasificación de crédito, donde los datos pueden ser limitados y ruidosos, la reducción del sobreajuste es un aspecto importante a considerar.
#
# ## Capacidad de manejar características categóricas:
# #### Random Forest es capaz de manejar características categóricas directamente sin requerir una codificación previa. Esto es beneficioso ya que el conjunto de datos incluye características categóricas como el género, el tipo de empleo o el estado civil, que son relevantes en la clasificación de crédito.
#
# ## Interpretabilidad y explicabilidad:
# #### Aunque Random Forest no proporciona una interpretación tan directa como algunos modelos lineales, es posible obtener información sobre la importancia relativa de las características. La importancia de las características se puede obtener mediante la medida de la ganancia de información o el índice Gini en los árboles individuales y luego promediando a través de todos los árboles del bosque. Esta información puede ser útil para entender que características son más relevantes para la clasificación de crédito.

# %%
X_train, X_test, y_train, y_test = train_test_split(df_svd, y, test_size=0.3, random_state=42)

# %%
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)
print("Exactitud (Accuracy):", accuracy_score(y_test, y_pred))
print("\nReporte de clasificación:")
print(classification_report(y_test, y_pred))
print("\nMatriz de confusión:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Exactitud (Accuracy): 0.8685204256779951
#
# Reporte de clasificación:
#               precision    recall  f1-score   support
#
#           No       0.88      0.98      0.93      2499
#          Yes       0.61      0.20      0.30       414
#
#     accuracy                           0.87      2913
#    macro avg       0.75      0.59      0.61      2913
# weighted avg       0.84      0.87      0.84      2913
#
#
# Matriz de confusión:
# [[2447   52]
#  [ 331   83]]

# %% [markdown]
# ## Observaciones:
#
# #### El modelo muestra una alta precisión en el conjunto de entrenamiento, pero una baja precisión en el conjunto de prueba.
# #### La precisión en el conjunto de entrenamiento es del 0.8654, lo cual es similar a la precisión global.
# #### La precisión en el conjunto de prueba es del 0.87, lo cual es ligeramente mayor que la precisión global.
# ####La precisión en el conjunto de prueba es relativamente baja en comparación con la precisión en el conjunto de entrenamiento.
# #### La precisión en ambos conjuntos de datos es relativamente alta, aunque la precisión para la clase "Yes" (sí) es más baja en comparación con la clase "No".
#
# ### Conclusión sobreajuste:
# #### Basándonos en las métricas proporcionadas, no parece haber un claro caso de sobreajuste. La diferencia entre la precisión en el conjunto de entrenamiento y el conjunto de prueba no es significativa y ambos valores son relativamente altos.
#
# ### Conclusión subajuste:
# #### Basándonos en las métricas proporcionadas, no parece haber un claro caso de subajuste. La precisión en ambos conjuntos de datos es relativamente alta y similar, aunque la precisión para la clase "Yes" es más baja.
#
# ### Conclusión general:
# #### En general, los resultados indican un rendimiento aceptable del modelo, aunque la precisión para la clase "Yes" es relativamente baja.

# %% [markdown]
# ## Sugerencias de mejora:
# #### Ajustar los hiperparámetros del modelo, como el número de árboles en el RandomForest para obtener una mejor generalización y rendimiento en la clase minoritaria.
#
# #### Explorar otras técnicas de modelado o algoritmos de clasificación para evaluar si se obtiene una mejora en el rendimiento.

# %% [markdown]
# #Aumento de arboles en RandomForest

# %%
rf = RandomForestClassifier(n_estimators=600, random_state=42)
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)
print("Exactitud (Accuracy):", accuracy_score(y_test, y_pred))
print("\nReporte de clasificación:")
print(classification_report(y_test, y_pred))
print("\nMatriz de confusión:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Exactitud (Accuracy): 0.8674905595605904
#
# Reporte de clasificación:
#               precision    recall  f1-score   support
#
#           No       0.88      0.98      0.93      2499
#          Yes       0.61      0.19      0.29       414
#
#     accuracy                           0.87      2913
#    macro avg       0.75      0.58      0.61      2913
# weighted avg       0.84      0.87      0.84      2913
#
#
# Matriz de confusión:
# [[2450   49]
#  [ 337   77]]

# %%
rf = RandomForestClassifier(n_estimators=1000, random_state=42)
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)
print("Exactitud (Accuracy):", accuracy_score(y_test, y_pred))
print("\nReporte de clasificación:")
print(classification_report(y_test, y_pred))
print("\nMatriz de confusión:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Exactitud (Accuracy): 0.8681771369721936
#
# Reporte de clasificación:
#               precision    recall  f1-score   support
#
#           No       0.88      0.98      0.93      2499
#          Yes       0.62      0.19      0.29       414
#
#     accuracy                           0.87      2913
#    macro avg       0.75      0.58      0.61      2913
# weighted avg       0.84      0.87      0.84      2913
#
#
# Matriz de confusión:
# [[2452   47]
#  [ 337   77]]

# %% [markdown]
# #### Si bien al aumentar el número de arboles aumenta la precisión del modelo el aumento no es tan significativo
#
# #### Se procedera a realizar cambio de otros hiperparametros:

# %%
rf = RandomForestClassifier(n_estimators=100, max_depth=30, min_samples_split=6, min_samples_leaf=4, max_features='sqrt', random_state=42)
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)
print("Exactitud (Accuracy):", accuracy_score(y_test, y_pred))
print("\nReporte de clasificación:")
print(classification_report(y_test, y_pred))
print("\nMatriz de confusión:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Exactitud (Accuracy): 0.8657741160315826
#
# Reporte de clasificación:
#               precision    recall  f1-score   support
#
#           No       0.87      0.99      0.93      2499
#          Yes       0.71      0.09      0.17       414
#
#     accuracy                           0.87      2913
#    macro avg       0.79      0.54      0.55      2913
# weighted avg       0.85      0.87      0.82      2913
#
#
# Matriz de confusión:
# [[2483   16]
#  [ 375   39]]

# %% [markdown]
# #### Luego de probar diferentes combinaciones de hiperparámetros no se logro un aumento significativo de la precisión asi que se decidio realizar una búsqueda de los mejores hiperparámetros :

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
param_grid = {
    'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 1000],
    'max_depth': [5, 10, 15, 20, 25, 30, 35, 40, 45],
    'min_samples_split': [2, 5, 10, 12, 15, 17, 20],
    'min_samples_leaf': [1, 2, 4, 6, 8, 10, 12],
    'max_features': ['sqrt', 'log2']
}
rf = RandomForestClassifier(random_state=42)
random_search = RandomizedSearchCV(estimator=rf, param_distributions=param_grid, n_iter=10, cv=5, scoring='accuracy', random_state=42)
random_search.fit(X_train, y_train)
best_params = random_search.best_params_
print("Mejores hiperparámetros:", best_params)
best_rf = RandomForestClassifier(**best_params, random_state=42)
best_rf.fit(X_train, y_train)
y_pred = best_rf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Exactitud (Accuracy) con mejores hiperparámetros:", accuracy)
# Out:
# Mejores hiperparámetros: {'n_estimators': 600, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'log2', 'max_depth': 20}
# Exactitud (Accuracy) con mejores hiperparámetros: 0.8716100240302094

# %% [markdown]
# #### Luego de buscar los mejores hiperparámetros se los aplico al modelo logrando una precisión del 87%

# %%
rf = RandomForestClassifier(n_estimators=600, max_depth=20, min_samples_split=2, min_samples_leaf=1, max_features='log2', random_state=42)
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)
print("Exactitud (Accuracy):", accuracy_score(y_test, y_pred))
print("\nReporte de clasificación:")
print(classification_report(y_test, y_pred))
print("\nMatriz de confusión:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Exactitud (Accuracy): 0.8716100240302094
#
# Reporte de clasificación:
#               precision    recall  f1-score   support
#
#           No       0.88      0.99      0.93      2499
#          Yes       0.74      0.15      0.25       414
#
#     accuracy                           0.87      2913
#    macro avg       0.81      0.57      0.59      2913
# weighted avg       0.86      0.87      0.83      2913
#
#
# Matriz de confusión:
# [[2478   21]
#  [ 353   61]]

# %% [markdown]
# #### Aplicacion del modelo sin aplicar reduccion de la dimensionalidad

# %%
X = df[['Gender', 'Own_car', 'Own_property', 'Work_phone', 'Phone', 'Email', 'Unemployed', 'Num_children',
        'Num_family', 'Account_length', 'Total_income', 'Age', 'Years_employed', 'Income_type', 'Education_type',
        'Family_status', 'Housing_type', 'Occupation_type']]

# %%
X_encoded_SR = pd.get_dummies(X, columns=['Gender', 'Own_car', 'Own_property', 'Work_phone', 'Phone', 'Email',
                                       'Unemployed', 'Income_type', 'Education_type', 'Family_status',
                                       'Housing_type', 'Occupation_type'])

# %%
smote_SR = SMOTE(random_state=42)
X_balanced_SR, y_balanced_SR = smote.fit_resample(X_encoded_SR, y)

# %%
X_train_SR, X_test_SR, y_train_SR, y_test_SR = train_test_split(X_balanced_SR, y_balanced_SR, test_size=0.2, random_state=42)

# %%
from collections import Counter

# %%
train_counter = Counter(y_balanced_SR)
test_counter = Counter(y_test_SR)
print("Muestras de cada clase en el conjunto de entrenamiento balanceado:")
print(train_counter)
print("\nMuestras de cada clase en el conjunto de prueba:")
print(test_counter)
# Out:
# Muestras de cada clase en el conjunto de entrenamiento balanceado:
# Counter({'Yes': 8426, 'No': 8426})
#
# Muestras de cada clase en el conjunto de prueba:
# Counter({'Yes': 1691, 'No': 1680})

# %% [markdown]
# #### Luego de realizar el balance de calses mediante SMOTE se logro un buen balance entre las clases.
# #### Se entrenara el modelo con las clases balanceadas sin reduccion.

# %%
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train_SR, y_train_SR)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred_SR = model.predict(X_test_SR)
accuracy = accuracy_score(y_test_SR, y_pred_SR)

# %%
print("Exactitud (Accuracy):", accuracy)
print("\nReporte de clasificación:")
print(classification_report(y_test_SR, y_pred_SR))
print("\nMatriz de confusión:")
print(confusion_matrix(y_test_SR, y_pred_SR))
# Out:
# Exactitud (Accuracy): 0.9172352417680214
#
# Reporte de clasificación:
#               precision    recall  f1-score   support
#
#           No       0.86      0.99      0.92      1680
#          Yes       0.99      0.84      0.91      1691
#
#     accuracy                           0.92      3371
#    macro avg       0.93      0.92      0.92      3371
# weighted avg       0.93      0.92      0.92      3371
#
#
# Matriz de confusión:
# [[1670   10]
#  [ 269 1422]]

# %% [markdown]
# #### Luego de entrenar el modelo sin realizar la reduccion de la dimensionalidad del DF se obtubo una precision de un 91%.
# #### Se decide realizar una busqueda de los mejores hiperparametros con el fin de optimizar aun mas el modelo.

# %%
param_grid = {
    'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 1000],
    'max_depth': [5, 10, 15, 20, 25, 30, 35, 40, 45],
    'min_samples_split': [2, 5, 10, 12, 15, 17, 20],
    'min_samples_leaf': [1, 2, 4, 6, 8, 10, 12],
    'max_features': ['sqrt', 'log2']
}
model = RandomForestClassifier(random_state=42)
random_search = RandomizedSearchCV(estimator=rf, param_distributions=param_grid, n_iter=10, cv=5, scoring='accuracy', random_state=42)
random_search.fit(X_train_SR, y_train_SR)
best_params = random_search.best_params_
print("Mejores hiperparámetros:", best_params)
best_rf = RandomForestClassifier(**best_params, random_state=42)
best_rf.fit(X_train_SR, y_train_SR)
y_pred = best_rf.predict(X_test_SR)
accuracy = accuracy_score(y_test_SR, y_pred_SR)
print("Exactitud (Accuracy) con mejores hiperparámetros:", accuracy)
# Out:
# Mejores hiperparámetros: {'n_estimators': 600, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'log2', 'max_depth': 20}
# Exactitud (Accuracy) con mejores hiperparámetros: 0.9172352417680214

# %% [markdown]
# #### Luego de una busqueda de mejores hiperparametros no se obtuvo una mejora de la precision, se decide mantener los hiperparametros anteriores.
